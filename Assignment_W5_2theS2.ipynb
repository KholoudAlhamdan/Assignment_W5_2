# %% [markdown]
# <a href="https://colab.research.google.com/github/KholoudAlhamdan/Assignment_W5_2/blob/main/Assignment_W5_2theS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sda-fintech-cohort1-section2/W5C2.git
# Out:
# Cloning into 'W5C2'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 19 (delta 8), reused 7 (delta 2), pack-reused 0
# Unpacking objects: 100% (19/19), done.

# %%
# %cd W5C2
# Out:
# /content/W5C2/W5C2/W5C2/W5C2/W5C2/W5C2/W5C2

# %%
import yfinance
import numpy as np
import pandas as pd
import pandas
import yfinance as yf
from pandas_datareader import data as pdr
yf.pdr_override()

import cufflinks as cf
cf.set_config_file(offline=True)

import warnings
warnings.filterwarnings("ignore")


from ActMng import AccountManager
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
starting_capital = 100000
allocation = 0.8

symbol = 'SPY'

long_trend_days = 12
short_trend_days = 6

# %%
def fetch_data(symbol:str='SPY', start_date:str='2020', end_date:str=None):
    
    if end_date is None:
        end = pandas.Timestamp.now()
    else:
        end = end_date
    
    return pdr.get_data_yahoo(symbol, pandas.Timestamp(start_date), pandas.Timestamp(end))[['Open','Close']]
df = fetch_data(symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fast_trend = df.Open.rolling(window=short_trend_days).mean()
slow_trend = df.Open.rolling(window=long_trend_days).mean()

df['ma_fast'] = fast_trend
df['ma_slow'] = slow_trend
df[['Close','ma_fast','ma_slow']].plot()

# %%
df['trade_direction'] = np.sign(fast_trend-slow_trend)
df
# Out:
#                   Open       Close     ma_fast     ma_slow  trade_direction
# Date
# 2020-01-02  323.540009  324.869995         NaN         NaN              NaN
# 2020-01-03  321.160004  322.410004         NaN         NaN              NaN
# 2020-01-06  320.489990  323.640015         NaN         NaN              NaN
# 2020-01-07  323.019989  322.730011         NaN         NaN              NaN
# 2020-01-08  322.940002  324.450012         NaN         NaN              NaN
# ...                ...         ...         ...         ...              ...
# 2021-11-04  465.359985  466.910004  459.751658  456.872498              1.0
# 2021-11-05  469.279999  468.529999  462.054993  458.384997              1.0
# 2021-11-08  469.700012  468.929993  464.359996  459.879166              1.0
# 2021-11-09  469.320007  467.380005  465.863332  461.228333              1.0
# 2021-11-10  465.579987  463.619995  466.756663  462.169998              1.0
#
# [470 rows x 5 columns]

# %%
#Determine the direction of the moving average differences
df_trades = df['trade_direction'].dropna().diff().dropna().apply(np.sign).astype('int8')
df_trades = pandas.DataFrame(df_trades[df_trades !=0])

#Label our intended trades
df_trades['trade'] = df['trade_direction'].map({1:'Long',-1:'Short'})
df['trades'] = df_trades['trade']
df
# Out:
#                   Open       Close  ...  trade_direction  trades
# Date                                ...
# 2020-01-02  323.540009  324.869995  ...              NaN     NaN
# 2020-01-03  321.160004  322.410004  ...              NaN     NaN
# 2020-01-06  320.489990  323.640015  ...              NaN     NaN
# 2020-01-07  323.019989  322.730011  ...              NaN     NaN
# 2020-01-08  322.940002  324.450012  ...              NaN     NaN
# ...                ...         ...  ...              ...     ...
# 2021-11-04  465.359985  466.910004  ...              1.0     NaN
# 2021-11-05  469.279999  468.529999  ...              1.0     NaN
# 2021-11-08  469.700012  468.929993  ...              1.0     NaN
# 2021-11-09  469.320007  467.380005  ...              1.0     NaN
# 2021-11-10  465.579987  463.619995  ...              1.0     NaN
#
# [470 rows x 6 columns]

# %%
#Label our opening trade after removing our window period
df['trades'].replace(pandas.np.NaN,'None',inplace=True)
df = df.dropna()
df['trades'].iloc[0]=('Long' if df['trade_direction'].iloc[0]==1.0 else 'Short')
df
# Out:
#                   Open       Close  ...  trade_direction  trades
# Date                                ...
# 2020-01-17  331.700012  331.950012  ...              1.0    Long
# 2020-01-21  330.899994  331.299988  ...              1.0    None
# 2020-01-22  332.239990  331.339996  ...              1.0    None
# 2020-01-23  330.630005  331.720001  ...              1.0    None
# 2020-01-24  332.440002  328.769989  ...              1.0    None
# ...                ...         ...  ...              ...     ...
# 2021-11-04  465.359985  466.910004  ...              1.0    None
# 2021-11-05  469.279999  468.529999  ...              1.0    None
# 2021-11-08  469.700012  468.929993  ...              1.0    None
# 2021-11-09  469.320007  467.380005  ...              1.0    None
# 2021-11-10  465.579987  463.619995  ...              1.0    None
#
# [459 rows x 6 columns]

# %%
# Our trading strategy implementation - feel free to brose ActMng.py if you are curious.
trading_strategy = AccountManager(symbol=symbol,trades_df=df,starting_capital=starting_capital,allocation_amount=allocation)
results = trading_strategy.run()

# %%
#Here we can see a day by day breakdown of the account
results['result_df']
# Out:
#                   Open       Close  ...  position_changes  fees
# 2020-01-17  331.700012  331.950012  ...            241.18   1.0
# 2020-01-21  330.899994  331.299988  ...              0.00   0.0
# 2020-01-22  332.239990  331.339996  ...              0.00   0.0
# 2020-01-23  330.630005  331.720001  ...              0.00   0.0
# 2020-01-24  332.440002  328.769989  ...              0.00   0.0
# ...                ...         ...  ...               ...   ...
# 2021-11-04  465.359985  466.910004  ...              0.00   0.0
# 2021-11-05  469.279999  468.529999  ...              0.00   0.0
# 2021-11-08  469.700012  468.929993  ...              0.00   0.0
# 2021-11-09  469.320007  467.380005  ...              0.00   0.0
# 2021-11-10  465.579987  463.619995  ...           -235.19   1.0
#
# [459 rows x 11 columns]

# %%
# Here are our simulated orders as we would submit to an API endpoint for algorthmic trading. 
results['broker_orders']
# Out:
#            symbol                 date  ...    size exchange_fees
# 2020-01-17    SPY  2020-01-17 00:00:00  ...  241.18           1.0
# 2020-01-29    SPY  2020-01-29 00:00:00  ...  241.18           1.0
# 2020-01-29    SPY  2020-01-29 00:00:00  ...  241.66           1.0
# 2020-02-07    SPY  2020-02-07 00:00:00  ...  241.66           1.0
# 2020-02-07    SPY  2020-02-07 00:00:00  ...  235.86           1.0
# ...           ...                  ...  ...     ...           ...
# 2021-09-14    SPY  2021-09-14 00:00:00  ...  222.78           1.0
# 2021-09-14    SPY  2021-09-14 00:00:00  ...  222.82           1.0
# 2021-10-13    SPY  2021-10-13 00:00:00  ...  222.82           1.0
# 2021-10-13    SPY  2021-10-13 00:00:00  ...  235.19           1.0
# 2021-11-10    SPY  2021-11-10 00:00:00  ...  235.19           1.0
#
# [66 rows x 8 columns]

# %%
#Todo:

r_df = results['result_df']

# Calculate the Absolute Return of our trend-following trading strategy
absolute_return_tf = (r_df['account_val'].iloc[-1]-starting_capital)/starting_capital
print(f"Absolute_return_tf: %{np.round(absolute_return_tf,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_tf = ((r_df['account_val'].iloc[-1]/starting_capital)**(252/len(df)))-1
print(f"CAGR_tf: %{np.round(CAGR_tf,2)*100}")

# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_tf = (r_df.account_val.pct_change().mean()/r_df.account_val.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'account_val')
r_df.account_val.plot()
# Out:
# Absolute_return_tf: %35.0
# CAGR_tf: %18.0

# %%
#Todo:

r_df = results['result_df']

# Calculate the Absolute Return of a buy-and-hold strategy in the same period
absolute_return_bh = (r_df.Close.iloc[-1]-r_df.Open.iloc[0])/r_df.Open.iloc[0]
print(f"Absolute_return_bh: %{np.round(absolute_return_bh,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_bh = ((r_df.Close.iloc[-1]/r_df.Open.iloc[0])**(252/len(r_df)))-1
print(f"CAGR_bh: %{np.round(CAGR_bh,2)*100}")


# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_bh = (r_df.Close.pct_change().mean()/r_df.Close.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'close' returns and your initial capital value to generate an equity curve)
((r_df.Close.pct_change().dropna()+1).cumprod()*starting_capital).plot()
# Out:
# Absolute_return_bh: %22.0
# CAGR_bh: %11.0

# %%
#Todo - optional, below:
# Copy any of the code from above to new cells below, and see how changing the symbol, dates and trend parameters changes the performance
# Can you beat the reference implementation?

# %%
starting_capital = 200000
allocation = 0.8

symbol = 'LCID'

long_trend_days = 12
short_trend_days = 3

# %%
def fetch_data(symbol:str='LCID', start_date:str='2020', end_date:str=None):
    
    if end_date is None:
        end = pandas.Timestamp.now()
    else:
        end = end_date
    
    return pdr.get_data_yahoo(symbol, pandas.Timestamp(start_date), pandas.Timestamp(end))[['Open','Close']]
df = fetch_data(symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fast_trend = df.Open.rolling(window=short_trend_days).mean()
slow_trend = df.Open.rolling(window=long_trend_days).mean()

df['ma_fast'] = fast_trend
df['ma_slow'] = slow_trend
df[['Close','ma_fast','ma_slow']].plot()

# %%
df['trade_direction'] = np.sign(fast_trend-slow_trend)
df
# Out:
#                  Open      Close    ma_fast    ma_slow  trade_direction
# Date
# 2020-09-18  10.250000   9.890000        NaN        NaN              NaN
# 2020-09-21   9.900000   9.860000        NaN        NaN              NaN
# 2020-09-22   9.960000   9.880000  10.036667        NaN              NaN
# 2020-09-23   9.900000   9.850000   9.920000        NaN              NaN
# 2020-09-24   9.850000   9.770000   9.903333        NaN              NaN
# ...               ...        ...        ...        ...              ...
# 2021-11-04  37.380001  37.119999  35.391666  30.455833              1.0
# 2021-11-05  37.500000  41.799999  36.370000  31.517500              1.0
# 2021-11-08  43.540001  45.919998  39.473334  33.120833              1.0
# 2021-11-09  47.480000  44.779999  42.840000  35.075000              1.0
# 2021-11-10  42.299999  40.750000  44.440000  36.526667              1.0
#
# [290 rows x 5 columns]

# %%
#Determine the direction of the moving average differences
df_trades = df['trade_direction'].dropna().diff().dropna().apply(np.sign).astype('int8')
df_trades = pandas.DataFrame(df_trades[df_trades !=0])

#Label our intended trades
df_trades['trade'] = df['trade_direction'].map({1:'Long',-1:'Short'})
df['trades'] = df_trades['trade']
df
# Out:
#                  Open      Close    ma_fast    ma_slow  trade_direction trades
# Date
# 2020-09-18  10.250000   9.890000        NaN        NaN              NaN    NaN
# 2020-09-21   9.900000   9.860000        NaN        NaN              NaN    NaN
# 2020-09-22   9.960000   9.880000  10.036667        NaN              NaN    NaN
# 2020-09-23   9.900000   9.850000   9.920000        NaN              NaN    NaN
# 2020-09-24   9.850000   9.770000   9.903333        NaN              NaN    NaN
# ...               ...        ...        ...        ...              ...    ...
# 2021-11-04  37.380001  37.119999  35.391666  30.455833              1.0    NaN
# 2021-11-05  37.500000  41.799999  36.370000  31.517500              1.0    NaN
# 2021-11-08  43.540001  45.919998  39.473334  33.120833              1.0    NaN
# 2021-11-09  47.480000  44.779999  42.840000  35.075000              1.0    NaN
# 2021-11-10  42.299999  40.750000  44.440000  36.526667              1.0    NaN
#
# [290 rows x 6 columns]

# %%
#Label our opening trade after removing our window period
df['trades'].replace(pandas.np.NaN,'None',inplace=True)
df = df.dropna()
df['trades'].iloc[0]=('Long' if df['trade_direction'].iloc[0]==1.0 else 'Short')
df
# Out:
#                  Open      Close    ma_fast    ma_slow  trade_direction trades
# Date
# 2020-10-05   9.800000   9.710000   9.793333   9.886667             -1.0  Short
# 2020-10-06   9.740000   9.680000   9.756667   9.844167             -1.0   None
# 2020-10-07   9.720000   9.710000   9.753333   9.829167             -1.0   None
# 2020-10-08   9.700000   9.717000   9.720000   9.807500             -1.0   None
# 2020-10-09   9.760000   9.750000   9.726667   9.795833             -1.0   None
# ...               ...        ...        ...        ...              ...    ...
# 2021-11-04  37.380001  37.119999  35.391666  30.455833              1.0   None
# 2021-11-05  37.500000  41.799999  36.370000  31.517500              1.0   None
# 2021-11-08  43.540001  45.919998  39.473334  33.120833              1.0   None
# 2021-11-09  47.480000  44.779999  42.840000  35.075000              1.0   None
# 2021-11-10  42.299999  40.750000  44.440000  36.526667              1.0   None
#
# [279 rows x 6 columns]

# %%
# Our trading strategy implementation - feel free to brose ActMng.py if you are curious.
trading_strategy = AccountManager(symbol=symbol,trades_df=df,starting_capital=starting_capital,allocation_amount=allocation)
results = trading_strategy.run()

# %%
#Here we can see a day by day breakdown of the account
results['result_df']
# Out:
#                  Open      Close    ma_fast  ...  position  position_changes fees
# 2020-10-05   9.800000   9.710000   9.793333  ... -16326.53         -16326.53  1.0
# 2020-10-06   9.740000   9.680000   9.756667  ... -16326.53              0.00  0.0
# 2020-10-07   9.720000   9.710000   9.753333  ... -16326.53              0.00  0.0
# 2020-10-08   9.700000   9.717000   9.720000  ... -16326.53              0.00  0.0
# 2020-10-09   9.760000   9.750000   9.726667  ... -16326.53              0.00  0.0
# ...               ...        ...        ...  ...       ...               ...  ...
# 2021-11-04  37.380001  37.119999  35.391666  ...   4159.46              0.00  0.0
# 2021-11-05  37.500000  41.799999  36.370000  ...   4159.46              0.00  0.0
# 2021-11-08  43.540001  45.919998  39.473334  ...   4159.46              0.00  0.0
# 2021-11-09  47.480000  44.779999  42.840000  ...   4159.46              0.00  0.0
# 2021-11-10  42.299999  40.750000  44.440000  ...      0.00          -4159.46  1.0
#
# [279 rows x 11 columns]

# %%
# Here are our simulated orders as we would submit to an API endpoint for algorthmic trading. 
results['broker_orders']
# Out:
#            symbol                 date  ...      size exchange_fees
# 2020-10-05   LCID  2020-10-05 00:00:00  ...  16326.53           1.0
# 2020-10-13   LCID  2020-10-13 00:00:00  ...  16326.53           1.0
# 2020-10-13   LCID  2020-10-13 00:00:00  ...  16177.19           1.0
# 2020-10-15   LCID  2020-10-15 00:00:00  ...  16177.19           1.0
# 2020-10-15   LCID  2020-10-15 00:00:00  ...  16237.25           1.0
# 2020-10-30   LCID  2020-10-30 00:00:00  ...  16237.25           1.0
# 2020-10-30   LCID  2020-10-30 00:00:00  ...  16297.66           1.0
# 2020-11-02   LCID  2020-11-02 00:00:00  ...  16297.66           1.0
# 2020-11-02   LCID  2020-11-02 00:00:00  ...  16304.26           1.0
# 2020-11-05   LCID  2020-11-05 00:00:00  ...  16304.26           1.0
# 2020-11-05   LCID  2020-11-05 00:00:00  ...  15913.20           1.0
# 2020-11-11   LCID  2020-11-11 00:00:00  ...  15913.20           1.0
# 2020-11-11   LCID  2020-11-11 00:00:00  ...  15936.02           1.0
# 2020-11-13   LCID  2020-11-13 00:00:00  ...  15936.02           1.0
# 2020-11-13   LCID  2020-11-13 00:00:00  ...  15788.61           1.0
# 2021-01-06   LCID  2021-01-06 00:00:00  ...  15788.61           1.0
# 2021-01-06   LCID  2021-01-06 00:00:00  ...  15706.35           1.0
# 2021-01-12   LCID  2021-01-12 00:00:00  ...  15706.35           1.0
# 2021-01-12   LCID  2021-01-12 00:00:00  ...   6295.00           1.0
# 2021-02-25   LCID  2021-02-25 00:00:00  ...   6295.00           1.0
# 2021-02-25   LCID  2021-02-25 00:00:00  ...   5671.17           1.0
# 2021-03-16   LCID  2021-03-16 00:00:00  ...   5671.17           1.0
# 2021-03-16   LCID  2021-03-16 00:00:00  ...   5227.43           1.0
# 2021-03-23   LCID  2021-03-23 00:00:00  ...   5227.43           1.0
# 2021-03-23   LCID  2021-03-23 00:00:00  ...   5423.67           1.0
# 2021-04-09   LCID  2021-04-09 00:00:00  ...   5423.67           1.0
# 2021-04-09   LCID  2021-04-09 00:00:00  ...   6770.32           1.0
# 2021-04-12   LCID  2021-04-12 00:00:00  ...   6770.32           1.0
# 2021-04-12   LCID  2021-04-12 00:00:00  ...   6773.20           1.0
# 2021-04-27   LCID  2021-04-27 00:00:00  ...   6773.20           1.0
# 2021-04-27   LCID  2021-04-27 00:00:00  ...   6195.71           1.0
# 2021-05-04   LCID  2021-05-04 00:00:00  ...   6195.71           1.0
# 2021-05-04   LCID  2021-05-04 00:00:00  ...   6479.00           1.0
# 2021-05-20   LCID  2021-05-20 00:00:00  ...   6479.00           1.0
# 2021-05-20   LCID  2021-05-20 00:00:00  ...   6734.43           1.0
# 2021-06-16   LCID  2021-06-16 00:00:00  ...   6734.43           1.0
# 2021-06-16   LCID  2021-06-16 00:00:00  ...   6551.05           1.0
# 2021-06-25   LCID  2021-06-25 00:00:00  ...   6551.05           1.0
# 2021-06-25   LCID  2021-06-25 00:00:00  ...   4940.50           1.0
# 2021-07-08   LCID  2021-07-08 00:00:00  ...   4940.50           1.0
# 2021-07-08   LCID  2021-07-08 00:00:00  ...   5010.86           1.0
# 2021-07-27   LCID  2021-07-27 00:00:00  ...   5010.86           1.0
# 2021-07-27   LCID  2021-07-27 00:00:00  ...   3862.45           1.0
# 2021-08-02   LCID  2021-08-02 00:00:00  ...   3862.45           1.0
# 2021-08-02   LCID  2021-08-02 00:00:00  ...   3967.65           1.0
# 2021-08-12   LCID  2021-08-12 00:00:00  ...   3967.65           1.0
# 2021-08-12   LCID  2021-08-12 00:00:00  ...   3933.22           1.0
# 2021-08-17   LCID  2021-08-17 00:00:00  ...   3933.22           1.0
# 2021-08-17   LCID  2021-08-17 00:00:00  ...   4006.36           1.0
# 2021-09-13   LCID  2021-09-13 00:00:00  ...   4006.36           1.0
# 2021-09-13   LCID  2021-09-13 00:00:00  ...   4709.10           1.0
# 2021-10-05   LCID  2021-10-05 00:00:00  ...   4709.10           1.0
# 2021-10-05   LCID  2021-10-05 00:00:00  ...   4556.54           1.0
# 2021-10-19   LCID  2021-10-19 00:00:00  ...   4556.54           1.0
# 2021-10-19   LCID  2021-10-19 00:00:00  ...   4159.46           1.0
# 2021-11-10   LCID  2021-11-10 00:00:00  ...   4159.46           1.0
#
# [56 rows x 8 columns]

# %%
r_df = results['result_df']

# Calculate the Absolute Return of our trend-following trading strategy
absolute_return_tf = (r_df['account_val'].iloc[-1]-starting_capital)/starting_capital
print(f"Absolute_return_tf: %{np.round(absolute_return_tf,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_tf = ((r_df['account_val'].iloc[-1]/starting_capital)**(252/len(df)))-1
print(f"CAGR_tf: %{np.round(CAGR_tf,2)*100}")

# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_tf = (r_df.account_val.pct_change().mean()/r_df.account_val.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'account_val')
r_df.account_val.plot()
# Out:
# Absolute_return_tf: %-2.0
# CAGR_tf: %-2.0

# %%
r_df = results['result_df']

# Calculate the Absolute Return of a buy-and-hold strategy in the same period
absolute_return_bh = (r_df.Close.iloc[-1]-r_df.Open.iloc[0])/r_df.Open.iloc[0]
print(f"Absolute_return_bh: %{np.round(absolute_return_bh,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_bh = ((r_df.Close.iloc[-1]/r_df.Open.iloc[0])**(252/len(r_df)))-1
print(f"CAGR_bh: %{np.round(CAGR_bh,2)*100}")


# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_bh = (r_df.Close.pct_change().mean()/r_df.Close.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'close' returns and your initial capital value to generate an equity curve)
((r_df.Close.pct_change().dropna()+1).cumprod()*starting_capital).plot()
# Out:
# Absolute_return_bh: %22.0
# CAGR_bh: %11.0

# %%
starting_capital = 100000
allocation = 0.7

symbol = 'DIS'

long_trend_days = 9
short_trend_days = 3

# %%
def fetch_data(symbol:str='DIS', start_date:str='2020', end_date:str=None):
    
    if end_date is None:
        end = pandas.Timestamp.now()
    else:
        end = end_date
    
    return pdr.get_data_yahoo(symbol, pandas.Timestamp(start_date), pandas.Timestamp(end))[['Open','Close']]
df = fetch_data(symbol)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
fast_trend = df.Open.rolling(window=short_trend_days).mean()
slow_trend = df.Open.rolling(window=long_trend_days).mean()

df['ma_fast'] = fast_trend
df['ma_slow'] = slow_trend
df[['Close','ma_fast','ma_slow']].plot()

# %%
df['trade_direction'] = np.sign(fast_trend-slow_trend)
df
# Out:
#                   Open       Close     ma_fast     ma_slow  trade_direction
# Date
# 2020-01-02  145.289993  148.199997         NaN         NaN              NaN
# 2020-01-03  146.399994  146.500000         NaN         NaN              NaN
# 2020-01-06  145.539993  145.649994  145.743327         NaN              NaN
# 2020-01-07  145.990005  145.699997  145.976664         NaN              NaN
# 2020-01-08  145.490005  145.399994  145.673335         NaN              NaN
# ...                ...         ...         ...         ...              ...
# 2021-11-04  170.029999  170.279999  169.919998  170.232222             -1.0
# 2021-11-05  173.500000  175.630005  171.076665  170.632222              1.0
# 2021-11-08  178.690002  176.869995  174.073334  171.270001              1.0
# 2021-11-09  176.949997  175.110001  176.380000  171.845556              1.0
# 2021-11-10  174.690002  174.449997  176.776667  172.424445              1.0
#
# [470 rows x 5 columns]

# %%
#Determine the direction of the moving average differences
df_trades = df['trade_direction'].dropna().diff().dropna().apply(np.sign).astype('int8')
df_trades = pandas.DataFrame(df_trades[df_trades !=0])

#Label our intended trades
df_trades['trade'] = df['trade_direction'].map({1:'Long',-1:'Short'})
df['trades'] = df_trades['trade']
df
# Out:
#                   Open       Close  ...  trade_direction  trades
# Date                                ...
# 2020-01-02  145.289993  148.199997  ...              NaN     NaN
# 2020-01-03  146.399994  146.500000  ...              NaN     NaN
# 2020-01-06  145.539993  145.649994  ...              NaN     NaN
# 2020-01-07  145.990005  145.699997  ...              NaN     NaN
# 2020-01-08  145.490005  145.399994  ...              NaN     NaN
# ...                ...         ...  ...              ...     ...
# 2021-11-04  170.029999  170.279999  ...             -1.0     NaN
# 2021-11-05  173.500000  175.630005  ...              1.0    Long
# 2021-11-08  178.690002  176.869995  ...              1.0     NaN
# 2021-11-09  176.949997  175.110001  ...              1.0     NaN
# 2021-11-10  174.690002  174.449997  ...              1.0     NaN
#
# [470 rows x 6 columns]

# %%
#Label our opening trade after removing our window period
df['trades'].replace(pandas.np.NaN,'None',inplace=True)
df = df.dropna()
df['trades'].iloc[0]=('Long' if df['trade_direction'].iloc[0]==1.0 else 'Short')
df
# Out:
#                   Open       Close  ...  trade_direction  trades
# Date                                ...
# 2020-01-14  143.410004  145.199997  ...             -1.0   Short
# 2020-01-15  145.710007  144.320007  ...             -1.0    None
# 2020-01-16  145.089996  145.119995  ...             -1.0    None
# 2020-01-17  145.539993  144.330002  ...              1.0    Long
# 2020-01-21  144.240005  143.559998  ...             -1.0   Short
# ...                ...         ...  ...              ...     ...
# 2021-11-04  170.029999  170.279999  ...             -1.0    None
# 2021-11-05  173.500000  175.630005  ...              1.0    Long
# 2021-11-08  178.690002  176.869995  ...              1.0    None
# 2021-11-09  176.949997  175.110001  ...              1.0    None
# 2021-11-10  174.690002  174.449997  ...              1.0    None
#
# [462 rows x 6 columns]

# %%
# Our trading strategy implementation - feel free to brose ActMng.py if you are curious.
trading_strategy = AccountManager(symbol=symbol,trades_df=df,starting_capital=starting_capital,allocation_amount=allocation)
results = trading_strategy.run()

# %%
#Here we can see a day by day breakdown of the account
results['result_df']
# Out:
#                   Open       Close  ...  position_changes  fees
# 2020-01-14  143.410004  145.199997  ...           -488.11   1.0
# 2020-01-15  145.710007  144.320007  ...              0.00   0.0
# 2020-01-16  145.089996  145.119995  ...              0.00   0.0
# 2020-01-17  145.539993  144.330002  ...            964.07   2.0
# 2020-01-21  144.240005  143.559998  ...           -953.19   2.0
# ...                ...         ...  ...               ...   ...
# 2021-11-04  170.029999  170.279999  ...              0.00   0.0
# 2021-11-05  173.500000  175.630005  ...            580.51   2.0
# 2021-11-08  178.690002  176.869995  ...              0.00   0.0
# 2021-11-09  176.949997  175.110001  ...              0.00   0.0
# 2021-11-10  174.690002  174.449997  ...           -283.74   1.0
#
# [462 rows x 11 columns]

# %%
# Here are our simulated orders as we would submit to an API endpoint for algorthmic trading. 
results['broker_orders']
# Out:
#            symbol                 date  ...    size exchange_fees
# 2020-01-14    DIS  2020-01-14 00:00:00  ...  488.11           1.0
# 2020-01-17    DIS  2020-01-17 00:00:00  ...  488.11           1.0
# 2020-01-17    DIS  2020-01-17 00:00:00  ...  475.96           1.0
# 2020-01-21    DIS  2020-01-21 00:00:00  ...  475.96           1.0
# 2020-01-21    DIS  2020-01-21 00:00:00  ...  477.23           1.0
# ...           ...                  ...  ...     ...           ...
# 2021-10-29    DIS  2021-10-29 00:00:00  ...  296.54           1.0
# 2021-10-29    DIS  2021-10-29 00:00:00  ...  296.77           1.0
# 2021-11-05    DIS  2021-11-05 00:00:00  ...  296.77           1.0
# 2021-11-05    DIS  2021-11-05 00:00:00  ...  283.74           1.0
# 2021-11-10    DIS  2021-11-10 00:00:00  ...  283.74           1.0
#
# [140 rows x 8 columns]

# %%
r_df = results['result_df']

# Calculate the Absolute Return of our trend-following trading strategy
absolute_return_tf = (r_df['account_val'].iloc[-1]-starting_capital)/starting_capital
print(f"Absolute_return_tf: %{np.round(absolute_return_tf,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_tf = ((r_df['account_val'].iloc[-1]/starting_capital)**(252/len(df)))-1
print(f"CAGR_tf: %{np.round(CAGR_tf,2)*100}")

# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_tf = (r_df.account_val.pct_change().mean()/r_df.account_val.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'account_val')
r_df.account_val.plot()
# Out:
# Absolute_return_tf: %-28.999999999999996
# CAGR_tf: %-17.0

# %%
r_df = results['result_df']

# Calculate the Absolute Return of a buy-and-hold strategy in the same period
absolute_return_bh = (r_df.Close.iloc[-1]-r_df.Open.iloc[0])/r_df.Open.iloc[0]
print(f"Absolute_return_bh: %{np.round(absolute_return_bh,2)*100}")

# Calculate the CAGR or our trend-following trading strategy
CAGR_bh = ((r_df.Close.iloc[-1]/r_df.Open.iloc[0])**(252/len(r_df)))-1
print(f"CAGR_bh: %{np.round(CAGR_bh,2)*100}")


# Calculate the IR (Sharpe without RF-rate) of our trend-following trading strategy
information_ratio_bh = (r_df.Close.pct_change().mean()/r_df.Close.pct_change().std())*((252)**0.5)

#Plot the equity curve (hint: use 'close' returns and your initial capital value to generate an equity curve)
((r_df.Close.pct_change().dropna()+1).cumprod()*starting_capital).plot()
# Out:
# Absolute_return_bh: %22.0
# CAGR_bh: %11.0
